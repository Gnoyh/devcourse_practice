# %% [markdown]
# # 날씨 정보 조회

# %% [markdown]
# ## https://www.weather.go.kr/w/weather/forecast/short-term.do

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import seaborn as sns
import matplotlib.pyplot as plt

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.weather.go.kr/w/weather/forecast/short-term.do")
driver.implicitly_wait(1)

temps = driver.find_element(By.CLASS_NAME, "tchart").text

temps = [int(i) for i in temps.replace("℃", "").split("\n")]

print(temps)
# Out:
# [18, 16, 14, 12, 11, 10, 10, 9, 9, 8, 8, 7, 7, 7, 7, 7, 9, 11, 12]

# %%
sns.lineplot(x=[i for i in range(len(temps))], y=temps)
plt.ylim(min(temps) - 2, max(temps) + 2)
plt.title("Expected Temperature from now on")

plt.show()
