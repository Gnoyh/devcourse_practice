# %% [markdown]
# # Wordcloud

# %%
# %pip install wordcloud
# %pip install konlpy
# Out:
# Collecting wordcloudNote: you may need to restart the kernel to use updated packages.
#
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/301.4 kB 330.3 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/301.4 kB 950.9 kB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6 in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in c:\users\song\appdata\local\programs\python\python312\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/19.4 MB 825.8 kB/s eta 0:00:24
#     --------------------------------------- 0.3/19.4 MB 3.0 MB/s eta 0:00:07
#    - -------------------------------------- 0.8/19.4 MB 5.3 MB/s eta 0:00:04
#    -- ------------------------------------- 1.4/19.4 MB 6.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.0/19.4 MB 7.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.6/19.4 MB 8.4 MB/s eta 0:00:02
#    ------ --------------------------------- 3.2/19.4 MB 9.0 MB/s eta 0:00:02
#    ------- -------------------------------- 3.7/19.4 MB 9.1 MB/s eta 0:00:02
#    -------- ------------------------------- 3.9/19.4 MB 9.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.0/19.4 MB 9.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 5.6/19.4 MB 9.9 MB/s eta 0:00:02
#    ------------ --------------------------- 6.2/19.4 MB 10.2 MB/s eta 0:00:02
#    ------------- -------------------------- 6.8/19.4 MB 10.3 MB/s eta 0:00:02
#    --------------- ------------------------ 7.4/19.4 MB 10.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 7.9/19.4 MB 10.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.4/19.4 MB 10.5 MB/s eta 0:00:02
#    ------------------ --------------------- 8.9/19.4 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 9.4/19.4 MB 10.7 MB/s eta 0:00:01
#    -------------------- ------------------- 10.0/19.4 MB 10.8 MB/s eta 0:00:01
#    --------------------- ------------------ 10.4/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.9/19.4 MB 11.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 11.4/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------ --------------- 12.0/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------- -------------- 12.6/19.4 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 13.2/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.6/19.4 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 14.2/19.4 MB 12.8 MB/s eta 0:00:01
#    ------------------------------ --------- 14.8/19.4 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 15.4/19.4 MB 12.1 MB/s eta 0:00:01
#    -------------------------------- ------- 16.0/19.4 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.6/19.4 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.2/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 17.8/19.4 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  19.0/19.4 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 11.1 MB/s eta 0:00:00
# Downloading JPype1-1.5.0-cp312-cp312-win_amd64.whl (352 kB)
#    ---------------------------------------- 0.0/352.2 kB ? eta -:--:--
#    --------------------------------------- 352.2/352.2 kB 11.0 MB/s eta 0:00:00
# Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 15.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.8 MB 13.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.8 MB 13.0 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.1/3.8 MB 11.3 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 8.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.7/3.8 MB 8.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: lxml, JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0 lxml-5.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Hannanum

# %%
national_anthem = """
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
남산 위에 저 소나무 철갑을 두른 듯
바람 서리 불변함은 우리 기상일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
가을 하늘 공활한데 높고 구름 없이
밝은 달은 우리 가슴 일편단심일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
이 기상과 이 맘으로 충성을 다하여
괴로우나 즐거우나 나라 사랑하세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
"""

# %%
hannanum = Hannanum()
nouns = hannanum.nouns(national_anthem)

nouns[: 10]
# Out:
# ['동해물', '백두산', '하느님', '보우하사', '우리나라', '무궁화', '삼천리', '화', '강산', '사람']

# %%
counter = Counter(nouns)

counter
# Out:
# Counter({'무궁화': 4,
#          '삼천리': 4,
#          '화': 4,
#          '강산': 4,
#          '사람': 4,
#          '대한': 4,
#          '길': 4,
#          '보전하세': 4,
#          '우리': 2,
#          '동해물': 1,
#          '백두산': 1,
#          '하느님': 1,
#          '보우하사': 1,
#          '우리나라': 1,
#          '남산': 1,
#          '위': 1,
#          '소나무': 1,
#          '철갑': 1,
#          '듯': 1,
#          '불변': 1,
#          '기상일세': 1,
#          '하늘': 1,
#          '공활한데': 1,
#          '구름': 1,
#          '달': 1,
#          '가슴': 1,
#          '일편단심일세': 1,
#          '기상': 1,
#          '충성': 1,
#          '사랑하세': 1})

# %%
wordcloud = WordCloud(font_path="/Users/Song/fonts/tree.ttf", background_color="white", width=1000, height=1000)

img = wordcloud.generate_from_frequencies(counter)
plt.imshow(img)
