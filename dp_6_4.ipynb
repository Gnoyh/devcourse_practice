# %% [markdown]
# **환경 설정**

# %%
# !pip install ipython-sql==0.4.1
# !pip install SQLAlchemy==1.4.49
# Out:
# Collecting ipython-sql==0.4.1
#   Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Collecting prettytable<1 (from ipython-sql==0.4.1)
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython>=1.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (7.34.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (2.0.29)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (1.16.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=1.0->ipython-sql==0.4.1)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (4.9.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=1.0->ipython-sql==0.4.1) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=1.0->ipython-sql==0.4.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql==0.4.1) (0.2.13)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13696 sha256=e8c4221c2d4141cd72a457e09a38bfd10da1fa3159f591be08ea31110a3e98e7
#   Stored in directory: /root/.cache/pip/wheels/25/4b/07/18c5d92824315576e478206ea69df34a9e31958f6143eb0e31
# Successfully built prettytable
# Installing collected packages: prettytable, jedi, ipython-sql
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.10.0
#     Uninstalling prettytable-3.10.0:
#       Successfully uninstalled prettytable-3.10.0
#   Attempting uninstall: ipython-sql
#     Found existing installation: ipython-sql 0.5.0
#     Uninstalling ipython-sql-0.5.0:
#       Successfully uninstalled ipython-sql-0.5.0
# Successfully installed ipython-sql-0.4.1 jedi-0.19.1 prettytable-0.7.2
# Collecting SQLAlchemy==1.4.49
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy==1.4.49) (3.0.3)
# Installing collected packages: SQLAlchemy
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.29
#     Uninstalling SQLAlchemy-2.0.29:
#       Successfully uninstalled SQLAlchemy-2.0.29
# Successfully installed SQLAlchemy-1.4.49

# %%
# %load_ext sql

# %%
# ID와 PW를 자신의 환경에 맞게 수정
# %sql postgresql://guest:Guest1234@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev

# %% [markdown]
# ## JOIN:
#
# An SQL JOIN clause is used to combine rows from two or more tables, based on a common field between them.
#
# 왼쪽 테이블을 LEFT라고 하고 오른쪽 테이블을 RIGHT이라고 하자. JOIN의 결과는 방식에 상관없이 양쪽의 필드를 모두 가진 새로운 테이블을 만들어내게 됨. 조인의 방식에 따라 다음 두 가지가 달라짐:
#
# 1. 어떤 레코드들이 선택되는지?
# 2. 어떤 필드들이 채워지는지?

# %%
# %%sql
#
# DROP TABLE IF EXISTS raw_data.vital;
# CREATE TABLE raw_data.vital (
#     UserID int,
#     VitalID	int,
#     Date date,
#     Weight int
# );
# INSERT INTO raw_data.vital VALUES
# (100,	1, '2020-01-01', 75),
# (100, 3, '2020-01-02', 78),
# (101, 2, '2020-01-01', 90),
# (101, 4, '2020-01-02', 95);

# %%
# %%sql
#
# DROP TABLE IF EXISTS raw_data.alert;
# CREATE TABLE raw_data.alert (
#     AlertID int,
#     VitalID	int,
#     AlertType varchar(32),
#     Date date,
#     UserID int
# );
# INSERT INTO raw_data.alert VALUES
#  (1,	4, 'WeightIncrease', '2020-01-01', 101),
#  (2, NULL, 'MissingVital', '2020-01-04', 100),
#  (3, NULL, 'MissingVital', '2020-01-04', 101);

# %% [markdown]
# * INNER JOIN
# 1. 양쪽 테이블에서 매치가 되는 레코드들만 리턴함
# 2. 양쪽 테이블의 필드가 모두 채워진 상태로 리턴됨

# %%
# %%sql
#
# SELECT * FROM raw_data.Vital v
# JOIN raw_data.Alert a ON v.vitalID = a.vitalID;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101)]

# %% [markdown]
# * LEFT JOIN: 왼쪽 테이블의 레코드는 모두 리턴되며 오른쪽 테이블과 매칭이 되는 레코드들의 경우에는 오른쪽 테이블 레코드들의 컬럼들이 채워진 상태로 리턴됨. 매칭이 안되는 왼쪽 테이블 레코드들은 오른쪽 테이블에서 들어오는 필드들은 NULL로 채워짐

# %%
# %%sql
#
# SELECT * FROM raw_data.Vital v
# LEFT JOIN raw_data.Alert a ON v.vitalID = a.vitalID;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 4 rows affected.
# [(100, 1, datetime.date(2020, 1, 1), 75, None, None, None, None, None),
#  (100, 3, datetime.date(2020, 1, 2), 78, None, None, None, None, None),
#  (101, 2, datetime.date(2020, 1, 1), 90, None, None, None, None, None),
#  (101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101)]

# %% [markdown]
# * FULL JOIN (OUTER JOIN):
# 1. 왼쪽 테이블과 오른쪽 테이블의 모든 레코드들을 리턴함
# 2. 매칭되는 경우에만 양쪽 테이블들의 모든 필드들이 채워진 상태로 리턴됨

# %%
# %%sql
#
# SELECT * FROM raw_data.Vital v
# FULL JOIN raw_data.Alert a ON v.vitalID = a.vitalID;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [(101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (None, None, None, None, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (None, None, None, None, 3, None, 'MissingVital', datetime.date(2020, 1, 4), 101),
#  (101, 2, datetime.date(2020, 1, 1), 90, None, None, None, None, None),
#  (100, 1, datetime.date(2020, 1, 1), 75, None, None, None, None, None),
#  (100, 3, datetime.date(2020, 1, 2), 78, None, None, None, None, None)]

# %% [markdown]
# * CARTESIAN JOIN (CROSS JOIN): 조인 조건 없이 두 개 테이블의 내용을 모두 조합한 결과 레코드들을 생성

# %%
# %%sql
#
# SELECT *
# FROM (
#     SELECT vitalid  -- 1,2,3,4
#     FROM raw_data.vital
# )
# CROSS JOIN (
#     SELECT alertid   -- 1,2,3
#     FROM raw_data.alert
# );
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [(1, 1),
#  (1, 2),
#  (1, 3),
#  (3, 1),
#  (3, 2),
#  (3, 3),
#  (2, 1),
#  (2, 2),
#  (2, 3),
#  (4, 1),
#  (4, 2),
#  (4, 3)]

# %%
# %%sql
#
# SELECT * FROM raw_data.Vital v
# CROSS JOIN raw_data.Alert a;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [(100, 1, datetime.date(2020, 1, 1), 75, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (100, 3, datetime.date(2020, 1, 2), 78, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (101, 2, datetime.date(2020, 1, 1), 90, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (100, 1, datetime.date(2020, 1, 1), 75, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (100, 3, datetime.date(2020, 1, 2), 78, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (101, 2, datetime.date(2020, 1, 1), 90, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (101, 4, datetime.date(2020, 1, 2), 95, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (100, 1, datetime.date(2020, 1, 1), 75, 3, None, 'MissingVital', datetime.date(2020, 1, 4), 101),
#  (100, 3, datetime.date(2020, 1, 2), 78, 3, None, 'MissingVital', datetime.date(2020, 1, 4), 101),
#  (101, 2, datetime.date(2020, 1, 1), 90, 3, None, 'MissingVital', datetime.date(2020, 1, 4), 101),
#  (101, 4, datetime.date(2020, 1, 2), 95, 3, None, 'MissingVital', datetime.date(2020, 1, 4), 101)]

# %% [markdown]
# SELF JOIN

# %%
# %%sql
#
# SELECT * FROM raw_data.Vital v1
# JOIN raw_data.Vital v2 ON v1.vitalID = v2.vitalID;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 4 rows affected.
# [(100, 1, datetime.date(2020, 1, 1), 75, 100, 1, datetime.date(2020, 1, 1), 75),
#  (100, 3, datetime.date(2020, 1, 2), 78, 100, 3, datetime.date(2020, 1, 2), 78),
#  (101, 2, datetime.date(2020, 1, 1), 90, 101, 2, datetime.date(2020, 1, 1), 90),
#  (101, 4, datetime.date(2020, 1, 2), 95, 101, 4, datetime.date(2020, 1, 2), 95)]

# %% [markdown]
# ## Boolean과 COALESCE/NULLIF

# %%
# %%sql
#
# SELECT *
# FROM raw_data.boolean_test;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [(True,), (False,), (True,), (None,), (False,), (True,), (False,)]

# %%
# %%sql
#
# SELECT
#     COUNT(CASE WHEN flag = True THEN 1 END) true_cnt1,
#     COUNT(CASE WHEN flag is True THEN 1 END) true_cnt2,
#     COUNT(CASE WHEN flag is not False THEN 1 END) not_false_cnt
# FROM raw_data.boolean_test;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(3, 3, 4)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.boolean_test
# WHERE flag is NULL;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(1,)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.boolean_test
# WHERE flag = NULL;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(0,)]

# %% [markdown]
# 공백이 들어있는 필드이름 혹은 예약된 키워드를 필드이름으로 사용하려면?

# %%
# %%sql
#
# DROP TABLE IF EXISTS adhoc.keeyong_test;
# CREATE TABLE adhoc.keeyong_test (
#     group int primary key,
#     'mailing address' varchar(32)
# );
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# (psycopg2.errors.SyntaxError) syntax error at or near "group"
# LINE 2:     group int primary key,
#             ^
#
# [SQL: CREATE TABLE adhoc.keeyong_test (
#     group int primary key,
#     'mailing address' varchar(32)
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# CREATE TABLE adhoc.keeyong_test (
#     "group" int primary key,
#     "mailing address" varchar(32)
# );
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# DROP TABLE IF EXISTS adhoc.keeyong_test_null;
# CREATE TABLE adhoc.keeyong_test_null (
#     value int NOT NULL
# );
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
#
# INSERT INTO adhoc.keeyong_test_null VALUES (NULL);
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# (psycopg2.errors.InternalError_) Cannot insert a NULL value into column value
# DETAIL:
#   -----------------------------------------------
#   error:  Cannot insert a NULL value into column value
#   code:      8007
#   context:   query execution
#   query:     7237077
#   location:  column:1
#   process:   query0_118_7237077 [pid=7733]
#   -----------------------------------------------
#
#
# [SQL: INSERT INTO adhoc.keeyong_test_null VALUES (NULL);]
# (Background on this error at: https://sqlalche.me/e/14/2j85)

# %% [markdown]
# # **숙제 - 1**
#
# **채널별 월 매출액 테이블 만들기 (adhoc 스키마 밑에 CTAS로 본인 영문 이름을 포함해서 테이블 만들기)**
# 1.   session_timestamp, user_session_channel, channel, session_transaction 테이블들을 사용
#
# 2.   아래와 같은 필드로 구성
#     - month
#     - channel
#     - uniqueUsers (총방문 사용자)
#     - paidUsers (구매 사용자: refund한 경우도 판매로 고려)
#     - conversionRate (구매사용자 / 총방문 사용자)
#     - grossRevenue (refund 포함)
#     - netRevenue (refund 제외)

# %% [markdown]
# **1. 혹시 OUT JOIN이 필요한지, 테이별 점검 필요**

# %%
# %%sql
#
# select distinct sessionid from raw_data.session_timestamp
# minus
# select distinct sessionid from raw_data.user_session_channel
# ;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 0 rows affected.
# []

# %%
# %%sql
#
# select distinct sessionid from raw_data.user_session_channel
# minus
# select distinct sessionid from raw_data.session_timestamp
# ;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 0 rows affected.
# []

# %%
# %%sql
#
# select * from raw_data.session_transaction
# where amount <= 0
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [('3d194d58a6470121c92f29c1ee4c936f', False, 0),
#  ('50aaa83c9c2d1d1f3ebc6c732c1abc8c', False, 0),
#  ('7fbfc161a3b873bf2119c788ed93d1f4', False, 0),
#  ('d288a67e5fe3b80c0ccb9531e87d437a', False, 0),
#  ('dfc95d616451863a4fe614534e08261c', False, 0),
#  ('297b51d372955449d68d0b67ffda8c80', False, 0),
#  ('52660fd5af844425740f3a7bf5151008', False, 0),
#  ('99e17fbe90095024e6c982c85d43d150', False, 0),
#  ('d572948a93127fa250a9aa8a122a4403', False, 0),
#  ('e00747f11c12e85717de726cc6c2f188', False, 0)]

# %% [markdown]
# **2. Summary Table 만들기**

# %%
# %%sql
#
# SELECT LEFT(ts, 7) "month",  -- "year month"
#        channel,
#        COUNT(DISTINCT usc.userid) uniqueUsers,
#        COUNT(DISTINCT CASE WHEN amount > 0 THEN usc.userid END) paidUsers,
#        ROUND(paidUsers*100.0/NULLIF(uniqueUsers, 0),2) conversionRate,
#        SUM(amount) grossRevenue,
#        SUM(CASE WHEN refunded is False THEN amount END) netRevenue
#    FROM raw_data.user_session_channel usc
#    LEFT JOIN raw_data.session_timestamp t ON t.sessionid = usc.sessionid
#    LEFT JOIN raw_data.session_transaction st ON st.sessionid = usc.sessionid
#    GROUP BY 1, 2
#    ORDER BY 1, 2;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 42 rows affected.
# [('2019-05', 'Facebook', 247, 14, Decimal('5.67'), 1199, 997),
#  ('2019-05', 'Google', 253, 10, Decimal('3.95'), 580, 580),
#  ('2019-05', 'Instagram', 234, 11, Decimal('4.70'), 959, 770),
#  ('2019-05', 'Naver', 237, 11, Decimal('4.64'), 867, 844),
#  ('2019-05', 'Organic', 238, 17, Decimal('7.14'), 1846, 1571),
#  ('2019-05', 'Youtube', 244, 9, Decimal('3.69'), 529, 529),
#  ('2019-06', 'Facebook', 414, 22, Decimal('5.31'), 1578, 1578),
#  ('2019-06', 'Google', 412, 13, Decimal('3.16'), 947, 947),
#  ('2019-06', 'Instagram', 410, 21, Decimal('5.12'), 1462, 1418),
#  ('2019-06', 'Naver', 398, 15, Decimal('3.77'), 1090, 1090),
#  ('2019-06', 'Organic', 416, 14, Decimal('3.37'), 1129, 940),
#  ('2019-06', 'Youtube', 400, 17, Decimal('4.25'), 1042, 1042),
#  ('2019-07', 'Facebook', 558, 32, Decimal('5.73'), 2222, 2144),
#  ('2019-07', 'Google', 556, 21, Decimal('3.78'), 1558, 1385),
#  ('2019-07', 'Instagram', 567, 24, Decimal('4.23'), 1896, 1766),
#  ('2019-07', 'Naver', 553, 19, Decimal('3.44'), 1547, 1547),
#  ('2019-07', 'Organic', 557, 22, Decimal('3.95'), 1600, 1600),
#  ('2019-07', 'Youtube', 564, 36, Decimal('6.38'), 2210, 2037),
#  ('2019-08', 'Facebook', 611, 18, Decimal('2.95'), 1009, 1009),
#  ('2019-08', 'Google', 610, 27, Decimal('4.43'), 2210, 1894),
#  ('2019-08', 'Instagram', 621, 28, Decimal('4.51'), 2129, 2001),
#  ('2019-08', 'Naver', 626, 22, Decimal('3.51'), 1829, 1551),
#  ('2019-08', 'Organic', 608, 26, Decimal('4.28'), 1643, 1606),
#  ('2019-08', 'Youtube', 614, 18, Decimal('2.93'), 987, 950),
#  ('2019-09', 'Facebook', 597, 27, Decimal('4.52'), 2270, 2270),
#  ('2019-09', 'Google', 599, 25, Decimal('4.17'), 1872, 1691),
#  ('2019-09', 'Instagram', 588, 20, Decimal('3.40'), 1260, 1122),
#  ('2019-09', 'Naver', 592, 21, Decimal('3.55'), 1996, 1996),
#  ('2019-09', 'Organic', 592, 22, Decimal('3.72'), 1267, 1267),
#  ('2019-09', 'Youtube', 588, 15, Decimal('2.55'), 1301, 1301),
#  ('2019-10', 'Facebook', 698, 29, Decimal('4.15'), 1650, 1641),
#  ('2019-10', 'Google', 699, 30, Decimal('4.29'), 2150, 2098),
#  ('2019-10', 'Instagram', 707, 33, Decimal('4.67'), 2568, 2395),
#  ('2019-10', 'Naver', 713, 32, Decimal('4.49'), 2695, 2695),
#  ('2019-10', 'Organic', 709, 31, Decimal('4.37'), 2762, 2608),
#  ('2019-10', 'Youtube', 705, 34, Decimal('4.82'), 2492, 2319),
#  ('2019-11', 'Facebook', 688, 25, Decimal('3.63'), 1678, 1678),
#  ('2019-11', 'Google', 688, 26, Decimal('3.78'), 2286, 2235),
#  ('2019-11', 'Instagram', 669, 25, Decimal('3.74'), 2116, 2116),
#  ('2019-11', 'Naver', 667, 26, Decimal('3.90'), 2234, 1987),
#  ('2019-11', 'Organic', 677, 34, Decimal('5.02'), 2626, 2255),
#  ('2019-11', 'Youtube', 677, 45, Decimal('6.65'), 3532, 3331)]

# %%
# %%sql
#
# --혹시 기존에 생성되어 있으면 삭제
# DROP TABLE IF EXISTS adhoc.gnoyh_session_summary;
#
# --Summary Table 생성
# CREATE TABLE adhoc.gnoyh_session_summary
# AS
# SELECT TO_CHAR(ts, 'YYYY-MM') year_month,
#     usc.channel,
#     COUNT(DISTINCT usc.userid) unique_users,
#     COUNT(DISTINCT CASE WHEN amount>0 THEN userid END) paid_users,
#     ROUND(paid_users*100./NULLIF(unique_users,0),2) conversion_rate,
#     SUM(amount) gross_revenue,
#     SUM(CASE WHEN refunded is False THEN amount
#         ELSE 0 END) net_revenue
#   FROM raw_data.user_session_channel usc
#   JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
#   LEFT JOIN raw_data.session_transaction str ON usc.sessionid = str.sessionid
# GROUP BY 1, 2;
#
# --정상적으로 생성되었는지 확인
# SELECT * FROM adhoc.gnoyh_session_summary
# ORDER BY 1, 2;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# 42 rows affected.
# [('2019-05', 'Facebook', 247, 14, Decimal('5'), 1199, 997),
#  ('2019-05', 'Google', 253, 10, Decimal('3'), 580, 580),
#  ('2019-05', 'Instagram', 234, 11, Decimal('4'), 959, 770),
#  ('2019-05', 'Naver', 237, 11, Decimal('4'), 867, 844),
#  ('2019-05', 'Organic', 238, 17, Decimal('7'), 1846, 1571),
#  ('2019-05', 'Youtube', 244, 9, Decimal('3'), 529, 529),
#  ('2019-06', 'Facebook', 414, 22, Decimal('5'), 1578, 1578),
#  ('2019-06', 'Google', 412, 13, Decimal('3'), 947, 947),
#  ('2019-06', 'Instagram', 410, 21, Decimal('5'), 1462, 1418),
#  ('2019-06', 'Naver', 398, 15, Decimal('3'), 1090, 1090),
#  ('2019-06', 'Organic', 416, 14, Decimal('3'), 1129, 940),
#  ('2019-06', 'Youtube', 400, 17, Decimal('4'), 1042, 1042),
#  ('2019-07', 'Facebook', 558, 32, Decimal('5'), 2222, 2144),
#  ('2019-07', 'Google', 556, 21, Decimal('3'), 1558, 1385),
#  ('2019-07', 'Instagram', 567, 24, Decimal('4'), 1896, 1766),
#  ('2019-07', 'Naver', 553, 19, Decimal('3'), 1547, 1547),
#  ('2019-07', 'Organic', 557, 22, Decimal('3'), 1600, 1600),
#  ('2019-07', 'Youtube', 564, 36, Decimal('6'), 2210, 2037),
#  ('2019-08', 'Facebook', 611, 18, Decimal('2'), 1009, 1009),
#  ('2019-08', 'Google', 610, 27, Decimal('4'), 2210, 1894),
#  ('2019-08', 'Instagram', 621, 28, Decimal('4'), 2129, 2001),
#  ('2019-08', 'Naver', 626, 22, Decimal('3'), 1829, 1551),
#  ('2019-08', 'Organic', 608, 26, Decimal('4'), 1643, 1606),
#  ('2019-08', 'Youtube', 614, 18, Decimal('2'), 987, 950),
#  ('2019-09', 'Facebook', 597, 27, Decimal('4'), 2270, 2270),
#  ('2019-09', 'Google', 599, 25, Decimal('4'), 1872, 1691),
#  ('2019-09', 'Instagram', 588, 20, Decimal('3'), 1260, 1122),
#  ('2019-09', 'Naver', 592, 21, Decimal('3'), 1996, 1996),
#  ('2019-09', 'Organic', 592, 22, Decimal('3'), 1267, 1267),
#  ('2019-09', 'Youtube', 588, 15, Decimal('2'), 1301, 1301),
#  ('2019-10', 'Facebook', 698, 29, Decimal('4'), 1650, 1641),
#  ('2019-10', 'Google', 699, 30, Decimal('4'), 2150, 2098),
#  ('2019-10', 'Instagram', 707, 33, Decimal('4'), 2568, 2395),
#  ('2019-10', 'Naver', 713, 32, Decimal('4'), 2695, 2695),
#  ('2019-10', 'Organic', 709, 31, Decimal('4'), 2762, 2608),
#  ('2019-10', 'Youtube', 705, 34, Decimal('4'), 2492, 2319),
#  ('2019-11', 'Facebook', 688, 25, Decimal('3'), 1678, 1678),
#  ('2019-11', 'Google', 688, 26, Decimal('3'), 2286, 2235),
#  ('2019-11', 'Instagram', 669, 25, Decimal('3'), 2116, 2116),
#  ('2019-11', 'Naver', 667, 26, Decimal('3'), 2234, 1987),
#  ('2019-11', 'Organic', 677, 34, Decimal('5'), 2626, 2255),
#  ('2019-11', 'Youtube', 677, 45, Decimal('6'), 3532, 3331)]

# %%
# %%sql
#
# -- 과제 1
#
# WITH vt1 AS (
#   SELECT A.sessionid, A.userid, B.ts, A.channel, ROW_NUMBER() OVER (PARTITION BY A.userid ORDER BY B.ts) AS seq
#   FROM raw_data.user_session_channel AS A
#   INNER JOIN raw_data.session_timestamp AS B ON A.sessionid = B.sessionid
# ),
# vt2 AS (
#   SELECT A.sessionid, A.userid, B.ts, A.channel, ROW_NUMBER() OVER (PARTITION BY A.userid ORDER BY B.ts DESC) AS seq
#   FROM raw_data.user_session_channel AS A
#   INNER JOIN raw_data.session_timestamp AS B ON A.sessionid = B.sessionid
# )
#
# SELECT vt1.userid, vt1.channel AS first_channel, vt2.channel AS last_channel
# FROM vt1
# INNER JOIN vt2 ON vt1.userid = vt2.userid and vt1.seq = vt2.seq
# WHERE vt1.seq = 1
# ORDER BY 1
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 949 rows affected.
# [(27, 'Youtube', 'Instagram'),
#  (29, 'Naver', 'Naver'),
#  (33, 'Google', 'Youtube'),
#  (34, 'Youtube', 'Naver'),
#  (36, 'Naver', 'Youtube'),
#  (40, 'Youtube', 'Google'),
#  (41, 'Facebook', 'Youtube'),
#  (44, 'Naver', 'Instagram'),
#  (45, 'Youtube', 'Instagram'),
#  (59, 'Instagram', 'Instagram'),
#  (64, 'Youtube', 'Youtube'),
#  (65, 'Youtube', 'Organic'),
#  (68, 'Youtube', 'Organic'),
#  (69, 'Facebook', 'Instagram'),
#  (80, 'Organic', 'Naver'),
#  (84, 'Google', 'Youtube'),
#  (87, 'Youtube', 'Google'),
#  (97, 'Organic', 'Organic'),
#  (112, 'Facebook', 'Youtube'),
#  (113, 'Organic', 'Organic'),
#  (114, 'Instagram', 'Youtube'),
#  (117, 'Organic', 'Youtube'),
#  (163, 'Google', 'Naver'),
#  (173, 'Google', 'Organic'),
#  (181, 'Facebook', 'Instagram'),
#  (184, 'Youtube', 'Youtube'),
#  (187, 'Organic', 'Youtube'),
#  (191, 'Naver', 'Instagram'),
#  (192, 'Facebook', 'Google'),
#  (193, 'Google', 'Facebook'),
#  (196, 'Facebook', 'Naver'),
#  (197, 'Naver', 'Youtube'),
#  (198, 'Facebook', 'Google'),
#  (199, 'Naver', 'Instagram'),
#  (201, 'Instagram', 'Youtube'),
#  (203, 'Naver', 'Facebook'),
#  (204, 'Naver', 'Youtube'),
#  (207, 'Facebook', 'Youtube'),
#  (210, 'Google', 'Google'),
#  (213, 'Naver', 'Organic'),
#  (216, 'Instagram', 'Naver'),
#  (218, 'Google', 'Youtube'),
#  (222, 'Facebook', 'Google'),
#  (223, 'Youtube', 'Facebook'),
#  (225, 'Facebook', 'Naver'),
#  (226, 'Organic', 'Instagram'),
#  (227, 'Google', 'Google'),
#  (229, 'Google', 'Facebook'),
#  (230, 'Naver', 'Google'),
#  (231, 'Naver', 'Instagram'),
#  (232, 'Instagram', 'Naver'),
#  (233, 'Facebook', 'Organic'),
#  (236, 'Naver', 'Youtube'),
#  (237, 'Organic', 'Google'),
#  (240, 'Organic', 'Organic'),
#  (243, 'Youtube', 'Instagram'),
#  (246, 'Organic', 'Google'),
#  (248, 'Naver', 'Instagram'),
#  (250, 'Instagram', 'Facebook'),
#  (251, 'Facebook', 'Google'),
#  (253, 'Facebook', 'Youtube'),
#  (254, 'Facebook', 'Facebook'),
#  (255, 'Facebook', 'Instagram'),
#  (256, 'Naver', 'Instagram'),
#  (257, 'Instagram', 'Organic'),
#  (258, 'Google', 'Facebook'),
#  (259, 'Google', 'Naver'),
#  (260, 'Naver', 'Youtube'),
#  (262, 'Organic', 'Instagram'),
#  (264, 'Google', 'Facebook'),
#  (265, 'Facebook', 'Instagram'),
#  (266, 'Google', 'Instagram'),
#  (267, 'Instagram', 'Naver'),
#  (269, 'Facebook', 'Organic'),
#  (270, 'Facebook', 'Youtube'),
#  (272, 'Naver', 'Naver'),
#  (277, 'Naver', 'Naver'),
#  (278, 'Naver', 'Organic'),
#  (280, 'Google', 'Organic'),
#  (282, 'Naver', 'Facebook'),
#  (301, 'Naver', 'Facebook'),
#  (329, 'Naver', 'Youtube'),
#  (341, 'Naver', 'Facebook'),
#  (345, 'Google', 'Organic'),
#  (355, 'Google', 'Naver'),
#  (363, 'Naver', 'Facebook'),
#  (368, 'Organic', 'Youtube'),
#  (369, 'Youtube', 'Organic'),
#  (371, 'Google', 'Google'),
#  (385, 'Instagram', 'Organic'),
#  (409, 'Facebook', 'Organic'),
#  (420, 'Youtube', 'Facebook'),
#  (437, 'Organic', 'Instagram'),
#  (465, 'Organic', 'Youtube'),
#  (468, 'Instagram', 'Facebook'),
#  (473, 'Youtube', 'Naver'),
#  (474, 'Facebook', 'Naver'),
#  (494, 'Youtube', 'Facebook'),
#  (510, 'Naver', 'Facebook'),
#  (511, 'Google', 'Google'),
#  (533, 'Instagram', 'Google'),
#  (538, 'Youtube', 'Organic'),
#  (543, 'Naver', 'Instagram'),
#  (572, 'Organic', 'Naver'),
#  (586, 'Naver', 'Organic'),
#  (587, 'Youtube', 'Google'),
#  (599, 'Organic', 'Google'),
#  (626, 'Facebook', 'Google'),
#  (643, 'Facebook', 'Facebook'),
#  (645, 'Youtube', 'Organic'),
#  (654, 'Naver', 'Naver'),
#  (656, 'Google', 'Youtube'),
#  (661, 'Youtube', 'Google'),
#  (676, 'Instagram', 'Facebook'),
#  (682, 'Organic', 'Facebook'),
#  (683, 'Youtube', 'Youtube'),
#  (686, 'Instagram', 'Organic'),
#  (694, 'Google', 'Organic'),
#  (698, 'Organic', 'Facebook'),
#  (699, 'Youtube', 'Organic'),
#  (700, 'Instagram', 'Organic'),
#  (702, 'Instagram', 'Youtube'),
#  (706, 'Youtube', 'Facebook'),
#  (707, 'Facebook', 'Facebook'),
#  (708, 'Organic', 'Instagram'),
#  (710, 'Youtube', 'Organic'),
#  (711, 'Organic', 'Naver'),
#  (712, 'Organic', 'Google'),
#  (715, 'Instagram', 'Naver'),
#  (732, 'Organic', 'Facebook'),
#  (735, 'Organic', 'Google'),
#  (738, 'Google', 'Google'),
#  (744, 'Facebook', 'Naver'),
#  (750, 'Facebook', 'Google'),
#  (752, 'Organic', 'Facebook'),
#  (757, 'Google', 'Google'),
#  (763, 'Naver', 'Youtube'),
#  (765, 'Naver', 'Naver'),
#  (768, 'Organic', 'Youtube'),
#  (771, 'Facebook', 'Organic'),
#  (772, 'Youtube', 'Instagram'),
#  (774, 'Facebook', 'Naver'),
#  (778, 'Instagram', 'Instagram'),
#  (779, 'Instagram', 'Naver'),
#  (780, 'Instagram', 'Naver'),
#  (782, 'Google', 'Google'),
#  (785, 'Organic', 'Facebook'),
#  (786, 'Youtube', 'Naver'),
#  (787, 'Organic', 'Naver'),
#  (788, 'Naver', 'Facebook'),
#  (789, 'Google', 'Instagram'),
#  (790, 'Facebook', 'Google'),
#  (793, 'Organic', 'Organic'),
#  (795, 'Google', 'Google'),
#  (801, 'Facebook', 'Google'),
#  (803, 'Instagram', 'Organic'),
#  (805, 'Instagram', 'Facebook'),
#  (808, 'Organic', 'Facebook'),
#  (810, 'Instagram', 'Naver'),
#  (812, 'Google', 'Facebook'),
#  (822, 'Organic', 'Organic'),
#  (825, 'Naver', 'Google'),
#  (830, 'Organic', 'Instagram'),
#  (832, 'Youtube', 'Facebook'),
#  (836, 'Instagram', 'Facebook'),
#  (841, 'Naver', 'Organic'),
#  (845, 'Youtube', 'Facebook'),
#  (847, 'Google', 'Facebook'),
#  (849, 'Facebook', 'Google'),
#  (852, 'Google', 'Organic'),
#  (855, 'Naver', 'Naver'),
#  (858, 'Organic', 'Instagram'),
#  (867, 'Naver', 'Youtube'),
#  (873, 'Instagram', 'Naver'),
#  (876, 'Naver', 'Organic'),
#  (879, 'Facebook', 'Youtube'),
#  (881, 'Youtube', 'Youtube'),
#  (887, 'Facebook', 'Facebook'),
#  (889, 'Organic', 'Instagram'),
#  (891, 'Google', 'Youtube'),
#  (895, 'Youtube', 'Instagram'),
#  (897, 'Facebook', 'Organic'),
#  (899, 'Instagram', 'Instagram'),
#  (901, 'Youtube', 'Youtube'),
#  (905, 'Youtube', 'Instagram'),
#  (907, 'Naver', 'Naver'),
#  (909, 'Naver', 'Facebook'),
#  (911, 'Google', 'Facebook'),
#  (913, 'Organic', 'Naver'),
#  (917, 'Facebook', 'Youtube'),
#  (919, 'Naver', 'Instagram'),
#  (921, 'Organic', 'Facebook'),
#  (923, 'Organic', 'Facebook'),
#  (927, 'Naver', 'Organic'),
#  (929, 'Naver', 'Naver'),
#  (931, 'Youtube', 'Naver'),
#  (935, 'Organic', 'Facebook'),
#  (937, 'Instagram', 'Google'),
#  (939, 'Youtube', 'Instagram'),
#  (943, 'Naver', 'Google'),
#  (945, 'Naver', 'Facebook'),
#  (947, 'Naver', 'Youtube'),
#  (949, 'Instagram', 'Instagram'),
#  (951, 'Naver', 'Google'),
#  (953, 'Google', 'Organic'),
#  (955, 'Youtube', 'Google'),
#  (957, 'Google', 'Youtube'),
#  (961, 'Facebook', 'Youtube'),
#  (963, 'Youtube', 'Naver'),
#  (965, 'Facebook', 'Organic'),
#  (967, 'Facebook', 'Organic'),
#  (969, 'Instagram', 'Organic'),
#  (971, 'Naver', 'Facebook'),
#  (973, 'Organic', 'Facebook'),
#  (975, 'Youtube', 'Facebook'),
#  (977, 'Youtube', 'Facebook'),
#  (979, 'Organic', 'Naver'),
#  (981, 'Naver', 'Naver'),
#  (983, 'Instagram', 'Organic'),
#  (985, 'Google', 'Organic'),
#  (987, 'Youtube', 'Google'),
#  (989, 'Facebook', 'Naver'),
#  (993, 'Naver', 'Google'),
#  (995, 'Organic', 'Organic'),
#  (997, 'Google', 'Instagram'),
#  (998, 'Naver', 'Naver'),
#  (1001, 'Google', 'Youtube'),
#  (1003, 'Instagram', 'Google'),
#  (1005, 'Google', 'Organic'),
#  (1007, 'Youtube', 'Google'),
#  (1009, 'Youtube', 'Google'),
#  (1011, 'Google', 'Instagram'),
#  (1013, 'Facebook', 'Youtube'),
#  (1015, 'Naver', 'Naver'),
#  (1023, 'Instagram', 'Naver'),
#  (1027, 'Organic', 'Facebook'),
#  (1029, 'Organic', 'Organic'),
#  (1031, 'Organic', 'Naver'),
#  (1033, 'Youtube', 'Instagram'),
#  (1035, 'Instagram', 'Instagram'),
#  (1037, 'Organic', 'Google'),
#  (1039, 'Organic', 'Naver'),
#  (1041, 'Organic', 'Google'),
#  (1043, 'Organic', 'Instagram'),
#  (1045, 'Youtube', 'Google'),
#  (1047, 'Naver', 'Facebook'),
#  (1049, 'Naver', 'Youtube'),
#  (1051, 'Naver', 'Facebook'),
#  (1053, 'Youtube', 'Organic'),
#  (1055, 'Google', 'Instagram'),
#  (1059, 'Organic', 'Facebook'),
#  (1063, 'Google', 'Instagram'),
#  (1065, 'Facebook', 'Facebook'),
#  (1067, 'Google', 'Naver'),
#  (1069, 'Naver', 'Facebook'),
#  (1073, 'Google', 'Youtube'),
#  (1075, 'Organic', 'Facebook'),
#  (1079, 'Naver', 'Facebook'),
#  (1081, 'Facebook', 'Youtube'),
#  (1083, 'Naver', 'Google'),
#  (1085, 'Organic', 'Youtube'),
#  (1087, 'Facebook', 'Google'),
#  (1089, 'Organic', 'Youtube'),
#  (1091, 'Facebook', 'Instagram'),
#  (1093, 'Youtube', 'Youtube'),
#  (1095, 'Google', 'Organic'),
#  (1099, 'Naver', 'Instagram'),
#  (1103, 'Google', 'Instagram'),
#  (1105, 'Google', 'Google'),
#  (1109, 'Google', 'Google'),
#  (1111, 'Facebook', 'Youtube'),
#  (1115, 'Google', 'Google'),
#  (1117, 'Instagram', 'Organic'),
#  (1119, 'Google', 'Instagram'),
#  (1121, 'Google', 'Google'),
#  (1125, 'Naver', 'Instagram'),
#  (1127, 'Instagram', 'Facebook'),
#  (1133, 'Google', 'Facebook'),
#  (1135, 'Youtube', 'Naver'),
#  (1137, 'Facebook', 'Naver'),
#  (1139, 'Youtube', 'Organic'),
#  (1141, 'Google', 'Facebook'),
#  (1145, 'Youtube', 'Google'),
#  (1151, 'Google', 'Organic'),
#  (1153, 'Youtube', 'Google'),
#  (1155, 'Facebook', 'Naver'),
#  (1157, 'Google', 'Google'),
#  (1159, 'Organic', 'Google'),
#  (1163, 'Youtube', 'Naver'),
#  (1165, 'Google', 'Google'),
#  (1167, 'Youtube', 'Youtube'),
#  (1169, 'Naver', 'Facebook'),
#  (1171, 'Facebook', 'Naver'),
#  (1175, 'Naver', 'Organic'),
#  (1177, 'Naver', 'Instagram'),
#  (1179, 'Google', 'Google'),
#  (1181, 'Youtube', 'Youtube'),
#  (1183, 'Facebook', 'Google'),
#  (1185, 'Instagram', 'Instagram'),
#  (1187, 'Instagram', 'Instagram'),
#  (1189, 'Facebook', 'Facebook'),
#  (1191, 'Organic', 'Youtube'),
#  (1193, 'Organic', 'Facebook'),
#  (1195, 'Organic', 'Organic'),
#  (1197, 'Instagram', 'Google'),
#  (1199, 'Naver', 'Google'),
#  (1203, 'Facebook', 'Google'),
#  (1205, 'Organic', 'Instagram'),
#  (1211, 'Youtube', 'Youtube'),
#  (1213, 'Naver', 'Organic'),
#  (1215, 'Facebook', 'Naver'),
#  (1217, 'Youtube', 'Youtube'),
#  (1219, 'Naver', 'Google'),
#  (1221, 'Instagram', 'Organic'),
#  (1223, 'Instagram', 'Google'),
#  (1227, 'Naver', 'Youtube'),
#  (1229, 'Google', 'Organic'),
#  (1231, 'Organic', 'Organic'),
#  (1233, 'Facebook', 'Naver'),
#  (1237, 'Google', 'Facebook'),
#  (1239, 'Google', 'Instagram'),
#  (1241, 'Naver', 'Organic'),
#  (2706, 'Youtube', 'Facebook'),
#  (2708, 'Naver', 'Naver'),
#  (2710, 'Naver', 'Google'),
#  (2712, 'Facebook', 'Instagram'),
#  (2714, 'Facebook', 'Google'),
#  (2716, 'Youtube', 'Instagram'),
#  (2720, 'Instagram', 'Google'),
#  (2722, 'Google', 'Youtube'),
#  (2724, 'Youtube', 'Youtube'),
#  (2726, 'Facebook', 'Instagram'),
#  (2728, 'Organic', 'Naver'),
#  (2730, 'Facebook', 'Google'),
#  (2732, 'Youtube', 'Naver'),
#  (2734, 'Facebook', 'Facebook'),
#  (2738, 'Youtube', 'Naver'),
#  (2744, 'Organic', 'Organic'),
#  (2746, 'Organic', 'Google'),
#  (2748, 'Naver', 'Facebook'),
#  (2750, 'Instagram', 'Facebook'),
#  (2752, 'Google', 'Organic'),
#  (2754, 'Youtube', 'Instagram'),
#  (2758, 'Google', 'Youtube'),
#  (2760, 'Instagram', 'Organic'),
#  (2762, 'Youtube', 'Instagram'),
#  (2766, 'Naver', 'Facebook'),
#  (2768, 'Organic', 'Google'),
#  (2770, 'Youtube', 'Naver'),
#  (2772, 'Youtube', 'Instagram'),
#  (2776, 'Instagram', 'Facebook'),
#  (2778, 'Google', 'Google'),
#  (2780, 'Google', 'Youtube'),
#  (2784, 'Facebook', 'Naver'),
#  (2788, 'Youtube', 'Youtube'),
#  (2790, 'Organic', 'Youtube'),
#  (2792, 'Naver', 'Google'),
#  (2794, 'Instagram', 'Instagram'),
#  (2798, 'Instagram', 'Instagram'),
#  (2802, 'Google', 'Naver'),
#  (2804, 'Organic', 'Instagram'),
#  (2806, 'Instagram', 'Naver'),
#  (2808, 'Google', 'Naver'),
#  (3070, 'Youtube', 'Youtube'),
#  (3195, 'Google', 'Instagram'),
#  (5722, 'Youtube', 'Instagram')]

# %%
# %%sql
#
# -- 과제 2
#
# SELECT A.userid
# FROM raw_data.user_session_channel AS A
# JOIN raw_data.session_transaction AS B ON A.sessionid = B.sessionid
# GROUP BY 1
# ORDER BY SUM(B.amount) DESC
# LIMIT 10
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(989,),
#  (772,),
#  (1615,),
#  (654,),
#  (1651,),
#  (973,),
#  (262,),
#  (1099,),
#  (2682,),
#  (891,)]

# %%
# %%sql
#
# -- 과제 3
#
# SELECT LEFT(created_at, 7) AS month, ROUND(((COUNT(CASE WHEN score BETWEEN 9 and 10 THEN 1 END) - COUNT(CASE WHEN score BETWEEN 0 and 6 THEN 1 END))::FLOAT / COUNT(score)) * 100, 2) AS NPS
# FROM raw_data.nps
# GROUP BY 1
# ORDER BY 1
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [('2019-01', 2.36),
#  ('2019-02', 30.54),
#  ('2019-03', 52.91),
#  ('2019-04', 53.0),
#  ('2019-05', 54.52),
#  ('2019-06', 65.02),
#  ('2019-07', 64.51),
#  ('2019-08', 67.71),
#  ('2019-09', 37.95),
#  ('2019-10', 53.29),
#  ('2019-11', 61.29),
#  ('2019-12', 65.99)]
